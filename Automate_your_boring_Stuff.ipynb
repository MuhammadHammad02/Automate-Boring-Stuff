# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHammad02/Automate-Boring-Stuff/blob/main/Automate_your_boring_Stuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Allice" + "\tBob")
# Out:
# Allice	Bob

# %%
spam = 40
egg = 2
print(spam + egg)
# Out:
# 42

# %%
print('Hello, world!')
print('What is your name?')  # Ask for their name.
my_name = input('>')
print('It is good to meet you, ' + my_name)
print('The length of your name is:')
print(len(my_name))
print('What is your age?')  # Ask for their age.
my_age = input('>')
print('You will be ' + str(int(my_age) + 1) + ' in a year.')
# Out:
# Hello, world!
# What is your name?
# >hammad
# It is good to meet you, hammad
# The length of your name is:
# 6
# What is your age?
# >36
# You will be 37 in a year.
