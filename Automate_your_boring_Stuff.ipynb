# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadHammad02/Automate-Boring-Stuff/blob/main/Automate_your_boring_Stuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# While loop
# # New Section

# %%
spam = 0
while spam < 5:
  print("Hello automation")
  spam = spam + 1
# Out:
# Hello automation
# Hello automation
# Hello automation
# Hello automation
# Hello automation

# %%
name = ""
while name != "your name":
  print("Please type your name")
  name = input()
print("Thank you")
# Out:
# Please type your name
# your name
# Thank you

# %%
while True:
  print("Please type your name")
  name = input()
  if name == "hammad":
    break
print("Thank you")
# Out:
# Please type your name
# qasim
# Please type your name
# ahmed
# Please type your name
# hammad
# Thank you

# %%
print("My name is")
for i in range(5):
  print(f'Hammad five times\t  (' + str(i) + ')')
# Out:
# My name is
# Hammad five times	  (0)
# Hammad five times	  (1)
# Hammad five times	  (2)
# Hammad five times	  (3)
# Hammad five times	  (4)
